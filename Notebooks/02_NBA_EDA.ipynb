# %% [markdown]
# # NBA SNA

# %% [markdown]
# ## API

# %%
# !pip install nba_api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.9/254.9 KB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 37.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.1 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.1 which is incompatible.
# ...

# %%
from nba_api.stats.static import players
from nba_api.stats.static import teams
from nba_api.stats.endpoints import playercareerstats
#from nba_api.stats.endpoints import playbyplay
#from nba_api.stats.endpoints import assisttracker

# %% [markdown]
# ## Imports

# %%
url = 'https://raw.githubusercontent.com/Saffian-Asghar/NBA_Network_Analysis/main/data/careers.csv'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# !pip install --upgrade numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Try API

# %%
at = playbyplay.PlayByPlay(game_id='0021700807',start_period=1,end_period=1)
at

# %%
at.get_data_frames()[0]
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0   0021700807         2            12                   0       1
# 1   0021700807         4            10                   0       1
# 2   0021700807         7             2                   1       1
# 3   0021700807         8             4                   0       1
# 4   0021700807         9             2                  97       1
# ..         ...       ...           ...                 ...     ...
# 94  0021700807       135             1                   1       1
# 95  0021700807       137             6                   1       1
# 96  0021700807       139             1                   1       1
# 97  0021700807       141             5                   1       1
# 98  0021700807       143            13                   0       1
#
#    WCTIMESTRING PCTIMESTRING                               HOMEDESCRIPTION  \
# 0       8:11 PM        12:00                                          None
# ...

# %%
# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999') 

# pandas data frames (optional: pip install pandas)
career = career.get_data_frames()[0]

# json
#career.get_json()

# dictionary
#career.get_dict()

# %%
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203999   2015-16        00  1610612743               DEN        21.0
# 1     203999   2016-17        00  1610612743               DEN        22.0
# 2     203999   2017-18        00  1610612743               DEN        23.0
# 3     203999   2018-19        00  1610612743               DEN        24.0
# 4     203999   2019-20        00  1610612743               DEN        25.0
# 5     203999   2020-21        00  1610612743               DEN        26.0
# 6     203999   2021-22        00  1610612743               DEN        27.0
# 7     203999   2022-23        00  1610612743               DEN        27.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV  \
# 0  80  55  1733.0  307  ...   0.811   181   379   560  189   79   50  104
# 1  73  59  2038.0  494  ...   0.825   212   506   718  359   61   55  171
# ...

# %%
career.get_data_frames()[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          8 non-null      int64
#  1   SEASON_ID          8 non-null      object
#  2   LEAGUE_ID          8 non-null      object
#  3   TEAM_ID            8 non-null      int64
#  4   TEAM_ABBREVIATION  8 non-null      object
#  5   PLAYER_AGE         8 non-null      float64
#  6   GP                 8 non-null      int64
#  7   GS                 8 non-null      int64
#  8   MIN                8 non-null      float64
#  9   FGM                8 non-null      int64
#  10  FGA                8 non-null      int64
#  11  FG_PCT             8 non-null      float64
#  12  FG3M               8 non-null      int64
#  13  FG3A               8 non-null      int64
#  14  FG3_PCT            8 non-null      float64
#  15  FTM                8 non-null      int64
# ...

# %%
players.find_player_by_id(203999)
# Out:
# {'id': 203999,
#  'full_name': 'Nikola Jokic',
#  'first_name': 'Nikola',
#  'last_name': 'Jokic',
#  'is_active': True}

# %%
#players.get_inactive_players()

# %%
players.find_players_by_first_name('Lebron')
# Out:
# [{'id': 2544,
#   'full_name': 'LeBron James',
#   'first_name': 'LeBron',
#   'last_name': 'James',
#   'is_active': True}]

# %%
jugadores = pd.DataFrame.from_dict(players.get_players())

# %%
jugadores = pd.DataFrame.from_dict(players.get_players()).sort_values('id')
jugadores
# Out:
#            id           full_name first_name last_name  is_active
# 3825        2         Byron Scott      Byron     Scott      False
# 2581        3          Grant Long      Grant      Long      False
# 3800        7         Dan Schayes        Dan   Schayes      False
# 4266        9      Sedale Threatt     Sedale   Threatt      False
# 2345       12          Chris King      Chris      King      False
# ...       ...                 ...        ...       ...        ...
# 3421  1631342     Daeqwon Plowden    Daeqwon   Plowden       True
# 1160  1631347      Anthony Duruji    Anthony    Duruji       True
# 1529  1631371        Grant Golden      Grant    Golden       True
# 2364  1631452       Noah Kirkwood       Noah  Kirkwood       True
# 4656  1631466  Jeenathan Williams  Jeenathan  Williams       True
#
# [4831 rows x 5 columns]

# %%
jugadores.sort_values('id')
# Out:
#            id           full_name first_name last_name  is_active
# 3825        2         Byron Scott      Byron     Scott      False
# 2581        3          Grant Long      Grant      Long      False
# 3800        7         Dan Schayes        Dan   Schayes      False
# 4266        9      Sedale Threatt     Sedale   Threatt      False
# 2345       12          Chris King      Chris      King      False
# ...       ...                 ...        ...       ...        ...
# 3421  1631342     Daeqwon Plowden    Daeqwon   Plowden       True
# 1160  1631347      Anthony Duruji    Anthony    Duruji       True
# 1529  1631371        Grant Golden      Grant    Golden       True
# 2364  1631452       Noah Kirkwood       Noah  Kirkwood       True
# 4656  1631466  Jeenathan Williams  Jeenathan  Williams       True
#
# [4831 rows x 5 columns]

# %%
career.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          8 non-null      int64
#  1   SEASON_ID          8 non-null      object
#  2   LEAGUE_ID          8 non-null      object
#  3   TEAM_ID            8 non-null      int64
#  4   TEAM_ABBREVIATION  8 non-null      object
#  5   PLAYER_AGE         8 non-null      float64
#  6   GP                 8 non-null      int64
#  7   GS                 8 non-null      int64
#  8   MIN                8 non-null      float64
#  9   FGM                8 non-null      int64
#  10  FGA                8 non-null      int64
#  11  FG_PCT             8 non-null      float64
#  12  FG3M               8 non-null      int64
#  13  FG3A               8 non-null      int64
#  14  FG3_PCT            8 non-null      float64
#  15  FTM                8 non-null      int64
# ...

# %% [markdown]
# ## EDA

# %%
#headerList = ['PlayerID','SeasonId','LeagueID','TeamID','TeamAbbreviation','PlayerAge','GP','GS','Min','FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FTPCT','OREB','DREB','REB','AST','STL','BLK','TOV','PF','PTS','FullName']

# %%
df = pd.read_csv(url, sep=',', header=None)
df.columns = ['PlayerID','SeasonId','LeagueID','TeamID','TeamAbbreviation','PlayerAge','GP','GS','Min','FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FTPCT','OREB','DREB','REB','AST','STL','BLK','TOV','PF','PTS','FullName']
df.head()
# Out:
#    PlayerID SeasonId  LeagueID      TeamID TeamAbbreviation  PlayerAge  GP  \
# 0     76001  1990-91         0  1610612757              POR       23.0  43
# 1     76001  1991-92         0  1610612757              POR       24.0  71
# 2     76001  1992-93         0  1610612749              MIL       25.0  12
# 3     76001  1992-93         0  1610612738              BOS       25.0  63
# 4     76001  1992-93         0           0              TOT       25.0  75
#
#      GS     Min  FGM  ...   OREB   DREB    REB  AST   STL   BLK   TOV   PF  \
# 0   0.0   290.0   55  ...   27.0   62.0   89.0   12   4.0  12.0  22.0   39
# 1   1.0   934.0  178  ...   81.0  179.0  260.0   30  25.0  16.0  66.0  132
# 2   0.0   159.0   26  ...   12.0   25.0   37.0   10   6.0   4.0  13.0   24
# 3  52.0  1152.0  219  ...  114.0  186.0  300.0   17  19.0  22.0  84.0  165
# 4  52.0  1311.0  245  ...  126.0  211.0  337.0   27  25.0  26.0  97.0  189
#
#    PTS        FullName
# 0  135  Alaa Abdelnaby
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28039 entries, 0 to 28038
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PlayerID          28039 non-null  int64
#  1   SeasonId          28039 non-null  object
#  2   LeagueID          28039 non-null  int64
#  3   TeamID            28039 non-null  int64
#  4   TeamAbbreviation  28030 non-null  object
#  5   PlayerAge         28039 non-null  float64
#  6   GP                28039 non-null  int64
#  7   GS                21764 non-null  float64
#  8   Min               27295 non-null  float64
#  9   FGM               28039 non-null  int64
#  10  FGA               28039 non-null  int64
#  11  FG_PCT            28026 non-null  float64
#  12  FG3M              22200 non-null  float64
#  13  FG3A              22200 non-null  float64
#  14  FG3_PCT           21983 non-null  float64
#  15  FTM               28039 non-null  int64
# ...

# %%
df['TeamAbbreviation'].unique()
df['TeamAbbreviation'].nunique()
# Out:
# 75

# %%
##PlayersPerTeam = df.groupby(['TeamID'])['TeamID'].aggregate(['count']).reset_index()
#PlayersPerTeam.sort_values('count',ascending=False,inplace=True)
#PlayersPerTeam.drop(labels=0,inplace=True)
#PlayersPerTeam = PlayersPerTeam[PlayersPerTeam['count']>=391].reset_index()
#PlayersPerTeam[['TeamID', 'count']].merge(df[['TeamID','TeamAbbreviation']],on='TeamID')

# %%
#df[df['TeamAbbreviation']=='AND']

# %%
#teams.find_team_by_abbreviation('GSW')

# %%
teamsPlayers = df.groupby("TeamID").PlayerID.nunique().reset_index()
#teamsPlayers

# %%
teamsPlayers = teamsPlayers[['TeamID', 'PlayerID']].merge(df[['TeamID','TeamAbbreviation']],on='TeamID').drop_duplicates().sort_values('PlayerID',ascending=False)

# %%
current_teams = ['ATL','BOS','CHA','CHI','CLE','DAL','DEN','DET','GSW','HOU','IND','LAC','LAL','MEM','MIA','MIL','MIN','NOP','NYK','BKN','OKC','ORL','PHI','PHX','POR','SAS','SAC','TOR','UTH','WAS']
teamsPlayers = teamsPlayers.loc[teamsPlayers['TeamAbbreviation'].isin(current_teams)].sort_values('TeamAbbreviation')
teamsPlayers.drop(teamsPlayers.tail(1).index,inplace=True)

# %%
teamsPlayers.head()
# Out:
#            TeamID  PlayerID TeamAbbreviation
# 2883   1610612737       552              ATL
# 14830  1610612751       433              BKN
# 4007   1610612738       476              BOS
# 27483  1610612766       269              CHA
# 6417   1610612741       390              CHI

# %%
teamsPlayers.sort_values(by='PlayerID', ascending=False, inplace=True)
teamsPlayers['color'] = '#143D52'
# Set the color for specific players
teamsPlayers.loc[teamsPlayers['TeamAbbreviation'] == 'SAC', 'color'] = '#00BFFF'
teamsPlayers.loc[teamsPlayers['TeamAbbreviation'] == 'DET', 'color'] = '#00BFFF'
teamsPlayers.loc[teamsPlayers['TeamAbbreviation'] == 'PHI', 'color'] = '#00BFFF'
teamsPlayers.loc[teamsPlayers['TeamAbbreviation'] == 'GSW', 'color'] = '#00BFFF'
teamsPlayers.loc[teamsPlayers['TeamAbbreviation'] == 'BOS', 'color'] = '#00BFFF'
teamsPlayers.loc[teamsPlayers['TeamAbbreviation'] == 'NYK', 'color'] = '#00BFFF'
teamsPlayers.loc[teamsPlayers['TeamAbbreviation'] == 'LAL', 'color'] = '#00BFFF'
teamsPlayers.loc[teamsPlayers['TeamAbbreviation'] == 'ATL', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))

sns.barplot(data = teamsPlayers, x='TeamAbbreviation', y='PlayerID',palette=teamsPlayers['color'])
plt.xticks(rotation=60,fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Teams', fontsize=20)
plt.ylabel('Number of players', fontsize=20)
plt.title('Teams with most players in history', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(data = teamsPlayers, x='TeamAbbreviation', y='PlayerID').set_title('Players Per Team')
plt.xlabel("Teams")
plt.ylabel("Number of players")
# Out:
# Text(0, 0.5, 'Number of players')

# %% [markdown]
# # players in team

# %%
nodes =df.groupby(['PlayerID','TeamID'])['PlayerID'].aggregate(['count']).reset_index()
nodes = nodes[['TeamID', 'PlayerID']].merge(df[['PlayerID','FullName']],on='PlayerID').drop_duplicates().sort_values('PlayerID',ascending=False)
nodes = nodes[['TeamID', 'PlayerID','FullName']].merge(df[['TeamID','TeamAbbreviation']],on='TeamID', how='left').drop_duplicates().sort_values('TeamID',ascending=False)
current_teams = ['POR', 'MIL', 'BOS', 'TOT', 'SAC', 'PHL', 'CIN', 'SEA', 'HOU',
       'BUF', 'LAL', 'DEN', 'VAN', 'ORL', 'DAL', 'ATL', 'GOS', 'IND',
       'SYR', 'PIT', 'BOM', 'BAL', 'OKC', 'MIA', 'TOR', 'DET', 'LAC',
       'NYK', 'WAS', 'SDR', 'BKN', 'PHX', 'NJN', 'MEM', 'CHH', 'NOP',
       'CLE', 'CHI', 'NOJ', 'KCK', 'UTA', 'MIN', 'SAS', 'CHA', 'PHI',
       'SAN', 'NOH', 'SFW', 'NOK', 'UTH', 'STL', 'NYN', 'PHW', 'GSW',
       'FTW', 'DEF', 'BLT', 'CHS', 'SDC', 'DN', 'CLR', 'MNL', 'TCB',
       'INO', 'PRO', 'MIH', 'CHP', 'CHZ', 'HUS', 'JET', 'AND', 'WAT',
       'SHE', 'ROC', 'CAP']
nodes = nodes.loc[nodes['TeamAbbreviation'].isin(current_teams)].sort_values('TeamAbbreviation')

# %%
nodes.sample(39)
# Out:
#               TeamID  PlayerID            FullName TeamAbbreviation
# 4382866   1610612748    101123        Gerald Green              MIA
# 8774391   1610612762     76413        E.C. Coleman              NOJ
# 4178476   1610612766    101207      Kevin Burleson              CHH
# 11249361  1610612764      1740       Rashard Lewis              CHP
# 3218112   1610612764    201953         Eric Maynor              BLT
# 5014484   1610612758     78385         Bill Turner              CIN
# 4700305   1610612737     78529         Win Wilfong              ATL
# 10854236  1610612746      2030       Kenyon Martin              BUF
# 7261935   1610612758     77185          Jake Jones              SAC
# 7312143   1610612760     77167      Vinnie Johnson              OKC
# 6133998            0     77757       Jawann Oldham              TOT
# 7007788   1610612759     77331        John Lambert              SAS
# 5008257   1610612762     78386          Mel Turpin              NOJ
# ...

# %%
nodes[nodes['TeamID']==1610612762]
# Out:
#               TeamID  PlayerID           FullName TeamAbbreviation
# 13176872  1610612762       384    Calbert Cheaney              NOJ
# 507146    1610612762   1629597     Zylan Cheatham              NOJ
# 1921370   1610612762    203526          Raul Neto              NOJ
# 13367584  1610612762       323        Greg Foster              NOJ
# 10734103  1610612762      2052  DeShawn Stevenson              NOJ
# ...              ...       ...                ...              ...
# 11347794  1610612762      1721         Keon Clark              UTH
# 10391246  1610612762      2260     Jarron Collins              UTH
# 9390229   1610612762     76106        Jim Barnett              UTH
# 9294603   1610612762     76154        Kent Benson              UTH
# 6611227   1610612762     77528        Jim McElroy              UTH
#
# [969 rows x 4 columns]

# %%
nodes.sort_values('TeamID', ascending = False).sample(25)
# Out:
#               TeamID  PlayerID            FullName TeamAbbreviation
# 817408    1610612756   1628470        Torrey Craig              PHX
# 2592681   1610612758    202709         Cory Joseph              ROC
# 10676625  1610612737      2069       Hanno Mottola              TCB
# 13959399  1610612755       104     Benoit Benjamin              PHI
# 10415987  1610612751      2245        Damone Brown              NYN
# 12135861           0       976        Jeff McInnis              TOT
# 11966732  1610612739      1068       Greg Dreiling              CLE
# 8517300   1610612744     76555      George Dempsey              GSW
# 12628023  1610612737       754         Jim Jackson              ATL
# 12133345  1610612746       976        Jeff McInnis              LAC
# 8348      1610612763   1631222        Jake LaRavia              VAN
# 13607954  1610612744       221  Clar. Weatherspoon              SFW
# 3677337   1610612762    201178      Kyrylo Fesenko              UTH
# ...

# %%
df.TeamAbbreviation.unique()
# Out:
# array(['POR', 'MIL', 'BOS', 'TOT', 'SAC', 'PHL', 'CIN', 'SEA', 'HOU',
#        'BUF', 'LAL', 'DEN', 'VAN', 'ORL', 'DAL', 'ATL', 'GOS', 'IND',
#        'SYR', 'PIT', 'BOM', 'BAL', 'OKC', 'MIA', 'TOR', 'DET', 'LAC',
#        'NYK', 'WAS', 'SDR', 'BKN', 'PHX', 'NJN', 'MEM', 'CHH', 'NOP',
#        'CLE', 'CHI', 'NOJ', 'KCK', 'UTA', 'MIN', 'SAS', 'CHA', 'PHI',
#        'SAN', 'NOH', 'SFW', 'NOK', 'UTH', 'STL', 'NYN', 'PHW', 'GSW',
#        'FTW', 'DEF', 'BLT', 'CHS', 'SDC', 'DN', 'CLR', 'MNL', 'TCB',
#        'INO', 'PRO', 'MIH', 'CHP', 'CHZ', 'HUS', 'JET', 'AND', 'WAT',
#        'SHE', 'ROC', 'CAP', nan], dtype=object)

# %%
# Nikola Jokić
career1 = playercareerstats.PlayerCareerStats(player_id='201609') 

# pandas data frames (optional: pip install pandas)
career1 = career1.get_data_frames()[0]
career1
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201609   2008-09        00  1610612756               PHX        23.0
# 1      201609   2009-10        00  1610612756               PHX        24.0
# 2      201609   2010-11        00  1610612756               PHX        25.0
# 3      201609   2010-11        00  1610612745               HOU        25.0
# 4      201609   2010-11        00           0               TOT        25.0
# 5      201609   2011-12        00  1610612745               HOU        26.0
# 6      201609   2012-13        00  1610612756               PHX        27.0
# 7      201609   2013-14        00  1610612756               PHX        28.0
# 8      201609   2014-15        00  1610612756               PHX        29.0
# 9      201609   2014-15        00  1610612748               MIA        29.0
# 10     201609   2014-15        00           0               TOT        29.0
# ...

# %%
players.find_players_by_last_name('Booker')
# Out:
# [{'id': 1626164,
#   'full_name': 'Devin Booker',
#   'first_name': 'Devin',
#   'last_name': 'Booker',
#   'is_active': True},
#  {'id': 511,
#   'full_name': 'Melvin Booker',
#   'first_name': 'Melvin',
#   'last_name': 'Booker',
#   'is_active': False},
#  {'id': 202344,
#   'full_name': 'Trevor Booker',
#   'first_name': 'Trevor',
#   'last_name': 'Booker',
#   'is_active': False}]

# %%
# list of latest NBA team abbreviations
latest_abbreviations = ['ATL','BOS','CHA','CHI','CLE','DAL','DEN','DET','GSW','HOU','IND','LAC','LAL','MEM','MIA','MIL','MIN','NOP','NYK','BKN','OKC','ORL','PHI','PHX','POR','SAS','SAC','TOR','UTH','WAS']


# group data by team ID
grouped_data = df.groupby('TeamID')

# update team abbreviations
for team_id, group in grouped_data:
    match = group['TeamAbbreviation'].isin(latest_abbreviations)
    if match.any():
        abbreviation = group.loc[match,'TeamAbbreviation'].values[0]
        df.loc[group.index,'TeamAbbreviation'] = abbreviation

# save the updated dataframe
df.to_csv('updated_careers.csv')


# drop the old teams
df = df[~df['TeamAbbreviation'].isin(set(latest_abbreviations) ^ set(df['TeamAbbreviation'].unique()))]

# check the unique abbr

df['TeamAbbreviation'].nunique()
# Out:
# 30

# %%
df
# Out:
#        PlayerID SeasonId  LeagueID      TeamID TeamAbbreviation  PlayerAge  \
# 0         76001  1990-91         0  1610612757              POR       23.0
# 1         76001  1991-92         0  1610612757              POR       24.0
# 2         76001  1992-93         0  1610612749              MIL       25.0
# 3         76001  1992-93         0  1610612738              BOS       25.0
# 5         76001  1993-94         0  1610612738              BOS       26.0
# ...         ...      ...       ...         ...              ...        ...
# 28034   1627826  2019-20         0  1610612746              LAC       23.0
# 28035   1627826  2020-21         0  1610612746              LAC       24.0
# 28036   1627826  2021-22         0  1610612746              LAC       25.0
# 28037   1627826  2022-23         0  1610612746              LAC       25.0
# 28038     78650  1948-49         0  1610610036              WAS       29.0
#
# ...

# %%
player_teams = df.groupby(['PlayerID','FullName']).nunique()['TeamID'].reset_index()
player_teams_sorted = player_teams.sort_values('TeamID',ascending=False)
player_teams_sorted.head(10)

player_teams_sorted['color'] = '#143D52'
# Set the color for specific players
player_teams_sorted.loc[player_teams_sorted['FullName'] == 'LeBron James', 'color'] = '#00BFFF'
player_teams_sorted.loc[player_teams_sorted['FullName'] == 'Michael Jordan', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))
sns.barplot(x=player_teams_sorted['FullName'].head(20), y=player_teams_sorted['TeamID'].head(20),palette=player_teams_sorted['color'])
plt.xticks(rotation=60)
plt.xlabel('Players', fontsize=15)
plt.ylabel('Number of teams', fontsize=15)
plt.title('Top 20: Players Who Played for the Most Teams', fontsize=20)
plt.show()

# %% [markdown]
# ### Game Played

# %%
player_games= df.groupby(['PlayerID','FullName'])['GP'].sum().reset_index()
player_games = player_games.sort_values('GP',ascending=False)
player_games.head(10)

player_games['color'] = '#143D52'
# Set the color for specific players
player_games.loc[player_games['FullName'] == 'LeBron James', 'color'] = '#00BFFF'
player_games.loc[player_games['FullName'] == 'Michael Jordan', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))
sns.barplot(x=player_games['FullName'].head(20), y=player_games['GP'].head(20),palette=player_games['color'])
plt.xticks(rotation=60)
plt.xlabel('Players', fontsize=15)
plt.ylabel('Career games', fontsize=15)
plt.title('Top 20: Most Career Games', fontsize=20)
plt.show()

# %% [markdown]
# ### Career points

# %%
player_points= df.groupby(['PlayerID','FullName'])['PTS'].sum().reset_index()
player_points = player_points.sort_values('PTS',ascending=False)
player_points.head(10)

player_points['color'] = '#143D52'
# Set the color for specific players
player_points.loc[player_points['FullName'] == 'LeBron James', 'color'] = '#00BFFF'
player_points.loc[player_points['FullName'] == 'Michael Jordan', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))
sns.barplot(x=player_points['FullName'].head(20), y=player_points['PTS'].head(20),palette=player_points['color'])
plt.xticks(rotation=60)
plt.xlabel('Players', fontsize=15)
plt.ylabel('Career points', fontsize=15)
plt.title('Top 20: Most Career Points', fontsize=20)
plt.show()

# %% [markdown]
# ### Career Assists

# %%
player_ast= df.groupby(['PlayerID','FullName'])['AST'].sum().reset_index()
player_ast = player_ast.sort_values('AST',ascending=False)
player_ast.head(10)

player_ast['color'] = '#143D52'
# Set the color for specific players
player_ast.loc[player_ast['FullName'] == 'LeBron James', 'color'] = '#00BFFF'
player_ast.loc[player_ast['FullName'] == 'Michael Jordan', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))
sns.barplot(x=player_ast['FullName'].head(20), y=player_ast['AST'].head(20),palette=player_ast['color'])
plt.xticks(rotation=60)
plt.xlabel('Players', fontsize=15)
plt.ylabel('Career Assists', fontsize=15)
plt.title('Top 20: Most Career Assists', fontsize=20)
plt.show()

# %% [markdown]
# ### Career rebounds

# %%
player_reb= df.groupby(['PlayerID','FullName'])['REB'].sum().reset_index()
player_reb = player_reb.sort_values('REB',ascending=False)
player_reb.head(20)

player_reb['color'] = '#143D52'
# Set the color for specific players
player_reb.loc[player_reb['FullName'] == 'LeBron James', 'color'] = '#00BFFF'
player_reb.loc[player_reb['FullName'] == 'Michael Jordan', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))
sns.barplot(x=player_reb['FullName'].head(20), y=player_reb['REB'].head(20),palette=player_reb['color'])
plt.xticks(rotation=60)
plt.xlabel('Players', fontsize=15)
plt.ylabel('Career rebounds', fontsize=15)
plt.title('Top 20: Most Career Rebounds', fontsize=20)
plt.show()

# %% [markdown]
# ### Steals

# %%
player_stl= df.groupby(['PlayerID','FullName'])['STL'].sum().reset_index()
player_stl = player_stl.sort_values('STL',ascending=False)
player_stl.head(20)

player_stl['color'] = '#143D52'
# Set the color for specific players
player_stl.loc[player_stl['FullName'] == 'LeBron James', 'color'] = '#00BFFF'
player_stl.loc[player_stl['FullName'] == 'Michael Jordan', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))
sns.barplot(x=player_stl['FullName'].head(20), y=player_stl['STL'].head(20),palette=player_stl['color'])
plt.xticks(rotation=60)
plt.xlabel('Players', fontsize=15)
plt.ylabel('Career steals', fontsize=15)
plt.title('Top 20: Most Career Steals', fontsize=20)
plt.show()

# %% [markdown]
# ### 3PM

# %%
player_3p= df.groupby(['PlayerID','FullName'])['FG3M'].sum().reset_index()
player_3p = player_3p.sort_values('FG3M',ascending=False)
player_3p.head(10)

player_3p['color'] = '#143D52'
# Set the color for specific players
player_3p.loc[player_3p['FullName'] == 'LeBron James', 'color'] = '#00BFFF'
player_3p.loc[player_3p['FullName'] == 'Michael Jordan', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))
sns.barplot(x=player_3p['FullName'].head(20), y=player_3p['FG3M'].head(20),palette=player_3p['color'])
plt.xticks(rotation=60)
plt.xlabel('Players', fontsize=15)
plt.ylabel('Career 3PM' ,fontsize=15)
plt.title('Top 20: Most Career 3 Points Made', fontsize=20)
plt.show()

# %%
curiosity= df.groupby(['PlayerID','FullName'])['TOV'].sum().reset_index()
curiosity = curiosity.sort_values('TOV',ascending=False)
curiosity.head(20)

curiosity['color'] = '#143D52'
# Set the color for specific players
curiosity.loc[player_3p['FullName'] == 'LeBron James', 'color'] = '#00BFFF'
curiosity.loc[player_3p['FullName'] == 'Michael Jordan', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))
sns.barplot(x=curiosity['FullName'].head(20), y=curiosity['TOV'].head(20),palette=curiosity['color'])
plt.xticks(rotation=60)
plt.xlabel('Players', fontsize=15)
plt.ylabel('Career Turnovers' ,fontsize=15)
plt.title('Top 20: Most Career Turnovers', fontsize=20)
plt.show()

# %%
['PlayerID','SeasonId','LeagueID','TeamID','TeamAbbreviation','PlayerAge','GP','GS','Min','FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FTPCT','OREB','DREB','REB','AST','STL','BLK','TOV','PF','PTS','FullName']

# %% [markdown]
# # Team

# %%
import pandas as pd
import networkx as nx
import requests

# Retrieve data on LeBron James' teammates from the Open Basketball Database API
teams_url = "https://www.basketball-reference.com/teams/"
teams_html = requests.get(teams_url).content
teams_df = pd.read_html(teams_html)[0]

# %%
teams_df.drop(teams_df.columns[[1,2,9,10,11]], axis=1, inplace=True)

# %%
teams_df = teams_df[teams_df['To']=='2022-23']

# %%
teams_df = teams_df.drop_duplicates(subset='Franchise',keep='first').reset_index().drop(columns='To')

# %%
teams_df['TeamAbbreviation'] = ['ATL','BOS','BKN','CHA','CHI','CLE','DAL','DEN','DET','GSW','HOU','IND','LAC','LAL','MEM','MIA','MIL','MIN','NOP','NYK','OKC','ORL','PHI','PHX','POR','SAC','SAS','TOR','UTH','WAS']
teams_df
# Out:
#     index               Franchise  Yrs     G     W     L   W/L%  Champ  \
# 0       0           Atlanta Hawks   74  5822  2875  2947  0.494      1
# 1       5          Boston Celtics   77  5999  3548  2451  0.591     17
# 2       6           Brooklyn Nets   56  4495  1980  2515  0.440      2
# 3      12       Charlotte Hornets   33  2598  1139  1459  0.438      0
# 4      16           Chicago Bulls   57  4563  2326  2237  0.510      6
# 5      17     Cleveland Cavaliers   53  4238  1962  2276  0.463      1
# 6      18        Dallas Mavericks   43  3428  1734  1694  0.506      1
# 7      19          Denver Nuggets   56  4498  2291  2207  0.509      0
# 8      23         Detroit Pistons   75  5883  2808  3075  0.477      3
# 9      26   Golden State Warriors   77  5987  2903  3084  0.485      7
# 10     30         Houston Rockets   56  4490  2317  2173  0.516      2
# 11     33          Indiana Pacers   56  4498  2299  2199  0.511      3
# ...

# %%
teams_df.sort_values(by='Yrs', ascending=False, inplace=True)
teams_df['color'] = '#143D52'
# Set the color for specific players
#teams_df.loc[teams_df['TeamAbbreviation'] == 'SAC', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'DET', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'GSW', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'PHI', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'BOS', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'NYK', 'color'] = '#00BFFF'
teams_df.loc[teams_df['TeamAbbreviation'] == 'LAL', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'ATL', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))

sns.barplot(data = teams_df, x='TeamAbbreviation', y='Yrs',palette=teams_df['color'])
plt.xticks(rotation=60,fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Teams', fontsize=20)
plt.ylabel('Years', fontsize=20)
plt.title("Franchise's years", fontsize=25)
plt.show()

# %%
teams_df.sort_values(by='W/L%', ascending=False, inplace=True)
teams_df['color'] = '#143D52'
# Set the color for specific players
#teams_df.loc[teams_df['TeamAbbreviation'] == 'SAC', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'DET', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'GSW', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'PHI', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'BOS', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'NYK', 'color'] = '#00BFFF'
teams_df.loc[teams_df['TeamAbbreviation'] == 'LAL', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'ATL', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))

sns.barplot(data = teams_df, x='TeamAbbreviation', y='W/L%',palette=teams_df['color'])
plt.xticks(rotation=60,fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Teams', fontsize=20)
plt.ylabel('Win %', fontsize=20)
plt.title("Win % per team", fontsize=25)
plt.show()

# %%
teams_df.sort_values(by='Champ', ascending=False, inplace=True)
teams_df['color'] = '#143D52'
# Set the color for specific players
#teams_df.loc[teams_df['TeamAbbreviation'] == 'SAC', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'DET', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'GSW', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'PHI', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'BOS', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'NYK', 'color'] = '#00BFFF'
teams_df.loc[teams_df['TeamAbbreviation'] == 'LAL', 'color'] = '#00BFFF'
#teams_df.loc[teams_df['TeamAbbreviation'] == 'ATL', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))

sns.barplot(data = teams_df, x='TeamAbbreviation', y='Champ',palette=teams_df['color'])
plt.xticks(rotation=60,fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Teams', fontsize=20)
plt.ylabel('Championships', fontsize=20)
plt.title("Championships per team", fontsize=25)
plt.show()

# %%
teams2 = teams_df
teams2['ChampPerYear'] = teams2['Yrs']/teams2['Champ']
teams2

teams2.sort_values(by='ChampPerYear', ascending=False, inplace=True)
teams2['color'] = '#143D52'
# Set the color for specific players
#teams2.loc[teams2['TeamAbbreviation'] == 'SAC', 'color'] = '#00BFFF'
#teams2.loc[teams2['TeamAbbreviation'] == 'DET', 'color'] = '#00BFFF'
#teams2.loc[teams2['TeamAbbreviation'] == 'GSW', 'color'] = '#00BFFF'
#teams2.loc[teams2['TeamAbbreviation'] == 'PHI', 'color'] = '#00BFFF'
#teams2.loc[teams2['TeamAbbreviation'] == 'BOS', 'color'] = '#00BFFF'
#teams2.loc[teams2['TeamAbbreviation'] == 'NYK', 'color'] = '#00BFFF'
teams2.loc[teams2['TeamAbbreviation'] == 'LAL', 'color'] = '#00BFFF'
#teams2.loc[teams2['TeamAbbreviation'] == 'ATL', 'color'] = '#00BFFF'

# Plot the bar chart
plt.figure(figsize=(15,8))

sns.barplot(data = teams2, x='TeamAbbreviation', y='ChampPerYear',palette=teams_df['color'])
plt.xticks(rotation=60,fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Teams', fontsize=20)
plt.ylabel('Championships per Year', fontsize=20)
plt.title("Championships per Team", fontsize=25)
plt.show()
